# %%
# %config Completer.use_jedi = False

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samps = 5000

# %%
X = np.random.randn(2,samps)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X[0],X[1], alpha=0.3, s=2);
ax.set_aspect(1)
ax.set_xticks([-2,0,2])
ax.set_yticks([-2,0,2]);

# %%
X2 = X.copy()
X2[1] = X[1]+0.5*X[0]

# %%
X2svd = np.linalg.svd(X2@X2.T/samps)

# %%
Y = X2[1]-0.3*X2[0] + 0.2*np.random.randn(1,samps)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1])[0];
a2,b2 = X2svd[0][1]
line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2])[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3])[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
corr = (Y[0]*(a3*X2[0]+b3*X2[1])).sum()/np.sqrt((Y[0]**2).sum()*((a3*X2[0]+b3*X2[1])**2).sum())
ax.scatter(a3*X2[0]+b3*X2[1],Y[0], alpha=0.3, s=2, color = line3.get_color(), label = 'correlation = {:.2f}'.format(corr));
ax.set_aspect(1)
ax.spines['bottom'].set_color(line3.get_color());
ax.tick_params(axis='x', colors=line3.get_color())
ax.set_xlabel('$p_3$',fontsize=17, color=line3.get_color());
ax.set_ylabel('$y$',fontsize=17);
ax.set_yticks([-4,-2,0,2,4]);
# plt.legend(loc=1, fontsize=14);

leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
corr = (Y[0]*(a2*X2[0]+b2*X2[1])).sum()/np.sqrt((Y[0]**2).sum()*((a2*X2[0]+b2*X2[1])**2).sum())
ax.scatter(a2*X2[0]+b2*X2[1],Y[0], alpha=0.3, s=2, color = line2.get_color(), label = 'correlation = {:.2f}'.format(corr));
ax.set_aspect(1)
ax.spines['bottom'].set_color(line2.get_color());
ax.tick_params(axis='x', colors=line2.get_color())
ax.set_xlabel('$p_2$',fontsize=17, color=line2.get_color());
ax.set_ylabel('$y$',fontsize=17);
ax.set_yticks([-4,-2,0,2,4]);
ax.set_xlim(-4,4);

leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
corr = (Y[0]*(a1*X2[0]+b1*X2[1])).sum()/np.sqrt((Y[0]**2).sum()*((a1*X2[0]+b1*X2[1])**2).sum())
ax.scatter(a1*X2[0]+b1*X2[1],Y[0], alpha=0.3, s=2, color = line1.get_color(), label = 'correlation = {:.2f}'.format(corr));
ax.set_aspect(1)
ax.spines['bottom'].set_color(line1.get_color());
ax.tick_params(axis='x', colors=line1.get_color())
ax.set_xlabel('$p_1$',fontsize=17, color=line1.get_color());
ax.set_ylabel('$y$',fontsize=17);
ax.set_yticks([-4,-2,0,2,4]);

leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)

# %%
a4,b4 = 1,0.2
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(a4*X2[0]+b4*X2[1],Y[0], alpha=0.3, s=2, color = line1.get_color());
ax.set_aspect(1)
ax.spines['bottom'].set_color(line1.get_color());
ax.tick_params(axis='x', colors=line1.get_color())
ax.set_xlabel('$p_1$',fontsize=17, color=line1.get_color());
ax.set_ylabel('$y$',fontsize=17);
ax.set_yticks([-4,-2,0,2,4]);
(Y[0]*(a4*X2[0]+b4*X2[1])).sum()/np.sqrt((Y[0]**2).sum()*(a4*X2[0]+b4*X2[1]).sum())
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in sqrt
#   # This is added back by InteractiveShellApp.init_path()
# nan

# %% [markdown]
# ## 4D version

# %%
X2svd = np.linalg.svd(X2@X2.T/samps)

# %%
cmap = plt.get_cmap('tab10')

# %%
cmap(0)
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1])[0];
a2,b2 = X2svd[0][1]
line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2])[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3])[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

# %%
Y = np.random.randn(2,samps)
Y[0] = X2[1]-0.3*X2[0] + 0.2*np.random.randn(1,samps)

# %%
Ysvd = np.linalg.svd(Y@Y.T/samps)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$y_1$',fontsize=17);
ax.set_ylabel('$y_2$',fontsize=17);
a1y,b1y = -Ysvd[0][0]
line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3))[0];
a2y,b2y = -Ysvd[0][1]
line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(4))[0];
a3y,b3y = 1,0
line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5))[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

# %%
fig = plt.figure(figsize=(5,10))
ax = fig.add_subplot(211)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1])[0];
a2,b2 = X2svd[0][1]
line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2])[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3], color=cmap(2))[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

ax = fig.add_subplot(212)
ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$y_1$',fontsize=17);
ax.set_ylabel('$y_2$',fontsize=17);
a1y,b1y = -Ysvd[0][0]
line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3))[0];
a2y,b2y = -Ysvd[0][1]
line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(4))[0];
a3y,b3y = 1,0
line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5))[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

# %%
fig = plt.figure(figsize=(15,15))
for iy,ay,by in zip(range(3),[a1y,a2y,a3y],[b1y,b2y,b3y]):
    for ix,ax,bx in zip(range(3),[a1,a2,a3],[b1,b2,b3]):
        ax_ = fig.add_subplot(3,3,(ix+3*iy+1))
        Y_line = ay*Y[0]+by*Y[1]
        X_line = ax*X2[0]+bx*X2[1]
        corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
        ax_.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'correlation = {:.2f}'.format(corr));
        ax_.set_aspect(1)
        ax_.spines['bottom'].set_color(cmap(ix));
        ax_.tick_params(axis='x', colors=cmap(ix))
        ax_.set_xlabel('$xp_'+str(ix+1)+'$',fontsize=17, color=cmap(ix));
        ax_.spines['left'].set_color(cmap(iy+3));
        ax_.tick_params(axis='y', colors=cmap(iy+3))
        ax_.set_ylabel('$yp_'+str(iy+1)+'$',fontsize=17, color=cmap(iy+3));
        ax_.set_yticks([-4,-2,0,2,4]);
        # plt.legend(loc=1, fontsize=14);

        leg = ax_.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
        for item in leg.legendHandles:
            item.set_visible(False)
            
        ax_.set_xlim(-4,4);
        
        ax_.spines['bottom'].set_linewidth(3)
        ax_.spines['left'].set_linewidth(3)

# %%
fig = plt.figure(figsize=(5,10))
ax = fig.add_subplot(211)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1])[0];
a2,b2 = X2svd[0][1]
# line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2])[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3], color=cmap(2))[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

ax = fig.add_subplot(212)
ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$y_1$',fontsize=17);
ax.set_ylabel('$y_2$',fontsize=17);
a1y,b1y = -Ysvd[0][0]
# line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3))[0];
a2y,b2y = -Ysvd[0][1]
line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(4))[0];
a3y,b3y = 1,0
line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5))[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);

# %%
c=1
fig = plt.figure(figsize=(10,10))
for iy,ay,by in zip(range(3),[a1y,a2y,a3y],[b1y,b2y,b3y]):
    for ix,ax,bx in zip(range(3),[a1,a2,a3],[b1,b2,b3]):
        if iy==0: continue
        if ix==1: continue
        ax_ = fig.add_subplot(2,2,(c))
        Y_line = ay*Y[0]+by*Y[1]
        X_line = ax*X2[0]+bx*X2[1]
        corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
        ax_.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'correlation = {:.2f}'.format(corr));
        ax_.set_aspect(1)
        ax_.spines['bottom'].set_color(cmap(ix));
        ax_.tick_params(axis='x', colors=cmap(ix))
        ax_.set_xlabel('$xp_'+str(ix+1)+'$',fontsize=17, color=cmap(ix));
        ax_.spines['left'].set_color(cmap(iy+3));
        ax_.tick_params(axis='y', colors=cmap(iy+3))
        ax_.set_ylabel('$yp_'+str(iy+1)+'$',fontsize=17, color=cmap(iy+3));
        ax_.set_yticks([-4,-2,0,2,4]);
        # plt.legend(loc=1, fontsize=14);
        
        ax_.spines['bottom'].set_linewidth(3)
        ax_.spines['left'].set_linewidth(3)

        leg = ax_.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
        for item in leg.legendHandles:
            item.set_visible(False)
            
        ax_.set_xlim(-4,4);
        c+=1

# %%
fig = plt.figure(figsize=(10,19))
ax = fig.add_subplot(321)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1], linewidth=3)[0];
a2,b2 = X2svd[0][1]
# line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2])[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3], color=cmap(2), linewidth=3)[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);
ax.set_title('X point cloud',fontsize=15)

ax = fig.add_subplot(322)
ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$y_1$',fontsize=17);
ax.set_ylabel('$y_2$',fontsize=17);
a1y,b1y = -Ysvd[0][0]
# line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3))[0];
a2y,b2y = -Ysvd[0][1]
line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(4), linewidth=3)[0];
a3y,b3y = 1,0
line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5), linewidth=3)[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);
ax.set_title('Y point cloud',fontsize=15)

c=3
# fig = plt.figure(figsize=(10,10))
for iy,ay,by in zip(range(3),[a1y,a2y,a3y],[b1y,b2y,b3y]):
    for ix,ax,bx in zip(range(3),[a1,a2,a3],[b1,b2,b3]):
        if iy==0: continue
        if ix==1: continue
        ax_ = fig.add_subplot(3,2,(c))
        Y_line = ay*Y[0]+by*Y[1]
        X_line = ax*X2[0]+bx*X2[1]
        corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
        ax_.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'cross-correlation = {:.2f}'.format(corr));
        ax_.set_aspect(1)
        ax_.spines['bottom'].set_color(cmap(ix));
        ax_.tick_params(axis='x', colors=cmap(ix))
        ax_.set_xlabel('$xp_'+str(ix+1)+'$',fontsize=17, color=cmap(ix));
        ax_.spines['left'].set_color(cmap(iy+3));
        ax_.tick_params(axis='y', colors=cmap(iy+3))
        ax_.set_ylabel('$yp_'+str(iy+1)+'$',fontsize=17, color=cmap(iy+3));
        ax_.set_yticks([-4,-2,0,2,4]);
        # plt.legend(loc=1, fontsize=14);
        
        ax_.spines['bottom'].set_linewidth(3)
        ax_.spines['left'].set_linewidth(3)

        leg = ax_.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
        for item in leg.legendHandles:
            item.set_visible(False)
            
        ax_.set_xlim(-4,4);
        c+=1

# %%
fig = plt.figure(figsize=(20,13))
ax = fig.add_subplot(231)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1], linewidth=3, label='PCA')[0];
a2,b2 = X2svd[0][1]
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3], color=cmap(1), linewidth=3, ls='--', label='CCA')[0];
ax.set_ylim(-4,4);
ax.set_xlim(-4,4);
# ax.set_yticks([-3,0,3]);
ax.set_title('X point cloud',fontsize=15)
ax.legend(fancybox=True,loc=4, fontsize=14);

ax = fig.add_subplot(234)
ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$y_1$',fontsize=17);
ax.set_ylabel('$y_2$',fontsize=17);
a1y,b1y = -Ysvd[0][0]
# line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3))[0];
a2y,b2y = -Ysvd[0][1]
line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(2), linewidth=3, label='PCA')[0];
a3y,b3y = 1,0
line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5), linewidth=3, ls='--', label='CCA')[0];
ax.set_ylim(-4,4);
ax.set_xlim(-4,4);
# ax.set_yticks([-3,0,3]);
ax.set_title('Y point cloud',fontsize=15)
ax.legend(fancybox=True,loc=4, fontsize=14);

ax = fig.add_subplot(232)
Y_line = a2y*Y[0]+b2y*Y[1]
X_line = a1*X2[0]+b1*X2[1]
corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
ax.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'correlation = {:.2f}'.format(corr));
ax.spines['bottom'].set_color(cmap(0));
ax.tick_params(axis='x', colors=cmap(0))
ax.set_xlabel('$x_'+'{PCA}'+'$',fontsize=17, color=cmap(0));
ax.spines['left'].set_color(cmap(2));
ax.tick_params(axis='y', colors=cmap(2))
ax.set_ylabel('$y_'+'{PCA}'+'$',fontsize=17, color=cmap(2));
ax.set_ylim(-4,4);
ax.set_xlim(-4,4);
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)

ax = fig.add_subplot(233)
Y_line = a2y*Y[0]+b2y*Y[1]
X_line = a3*X2[0]+b3*X2[1]
corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
ax.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'correlation = {:.2f}'.format(corr));
ax.spines['bottom'].set_color(cmap(1));
ax.tick_params(axis='x', colors=cmap(1))
ax.set_xlabel('$x_'+'{CCA}'+'$',fontsize=17, color=cmap(1));
ax.spines['left'].set_color(cmap(2));
ax.tick_params(axis='y', colors=cmap(2))
ax.set_ylabel('$y_'+'{PCA}'+'$',fontsize=17, color=cmap(2));
ax.set_ylim(-4,4);
ax.set_xlim(-4,4);
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)

ax = fig.add_subplot(235)
Y_line = a3y*Y[0]+b3y*Y[1]
X_line = a1*X2[0]+b1*X2[1]
corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
ax.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'correlation = {:.2f}'.format(corr));
ax.spines['bottom'].set_color(cmap(0));
ax.tick_params(axis='x', colors=cmap(0))
ax.set_xlabel('$x_'+'{PCA}'+'$',fontsize=17, color=cmap(0));
ax.spines['left'].set_color(cmap(5));
ax.tick_params(axis='y', colors=cmap(5))
ax.set_ylabel('$y_'+'{CCA}'+'$',fontsize=17, color=cmap(5));
ax.set_ylim(-4,4);
ax.set_xlim(-4,4);
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)

ax = fig.add_subplot(236)
Y_line = a3y*Y[0]+b3y*Y[1]
X_line = a3*X2[0]+b3*X2[1]
corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
ax.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'correlation = {:.2f}'.format(corr));
ax.spines['bottom'].set_color(cmap(1));
ax.tick_params(axis='x', colors=cmap(1))
ax.set_xlabel('$x_'+'{CCA}'+'$',fontsize=17, color=cmap(1));
ax.spines['left'].set_color(cmap(5));
ax.tick_params(axis='y', colors=cmap(5))
ax.set_ylabel('$y_'+'{CCA}'+'$',fontsize=17, color=cmap(5));
ax.set_ylim(-4,4);
ax.set_xlim(-4,4);
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
leg = ax.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
for item in leg.legendHandles:
    item.set_visible(False)
    
# plt.show()
plt.savefig('cca_demo.png', dpi=300, transparent='true', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(14,19))
ax = fig.add_subplot(431)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1], linewidth=3)[0];
a2,b2 = X2svd[0][1]
line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2], linewidth=3)[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3], color=cmap(2), linewidth=3)[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);
ax.set_title('X point cloud',fontsize=15)

ax = fig.add_subplot(432)
ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$y_1$',fontsize=17);
ax.set_ylabel('$y_2$',fontsize=17);
a1y,b1y = -Ysvd[0][0]
line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3), linewidth=3)[0];
a2y,b2y = -Ysvd[0][1]
line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(4), linewidth=3)[0];
a3y,b3y = 1,0
line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5), linewidth=3)[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);
ax.set_title('Y point cloud',fontsize=15)

c=4
# fig = plt.figure(figsize=(10,10))
for iy,ay,by in zip(range(3),[a1y,a2y,a3y],[b1y,b2y,b3y]):
    for ix,ax,bx in zip(range(3),[a1,a2,a3],[b1,b2,b3]):
#         if iy==0: continue
#         if ix==1: continue
        ax_ = fig.add_subplot(4,3,(c))
        Y_line = ay*Y[0]+by*Y[1]
        X_line = ax*X2[0]+bx*X2[1]
        corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
        ax_.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'cross-correlation = {:.2f}'.format(corr));
        ax_.set_aspect(1)
        ax_.spines['bottom'].set_color(cmap(ix));
        ax_.tick_params(axis='x', colors=cmap(ix))
        ax_.set_xlabel('$xp_'+str(ix+1)+'$',fontsize=17, color=cmap(ix));
        ax_.spines['left'].set_color(cmap(iy+3));
        ax_.tick_params(axis='y', colors=cmap(iy+3))
        ax_.set_ylabel('$yp_'+str(iy+1)+'$',fontsize=17, color=cmap(iy+3));
        ax_.set_yticks([-4,-2,0,2,4]);
        # plt.legend(loc=1, fontsize=14);
        
        ax_.spines['bottom'].set_linewidth(3)
        ax_.spines['left'].set_linewidth(3)

        leg = ax_.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
        for item in leg.legendHandles:
            item.set_visible(False)
            
        ax_.set_xlim(-4,4);
        c+=1

# %%
fig = plt.figure(figsize=(22,5))
ax = fig.add_subplot(141)
ax.scatter(X2[0],X2[1], alpha=0.2, s=2, color='black');
ax.set_aspect(1)
# ax.set_ylim(-4,4);
ax.set_xlabel('$x_1$',fontsize=17);
ax.set_ylabel('$x_2$',fontsize=17);
a1,b1 = -X2svd[0][0]
line1 = ax.plot([-10*a1,10*a1],[-10*b1,10*b1], linewidth=3)[0];
a2,b2 = X2svd[0][1]
line2 = ax.plot([-10*a2,10*a2],[-10*b2,10*b2], linewidth=3)[0];
a3,b3 = -0.2,1
line3 = ax.plot([-10*a3,10*a3],[-10*b3,10*b3], color=cmap(2), linewidth=3)[0];
ax.set_ylim(-4.3,4.3);
ax.set_xlim(-3.6,3.6);
ax.set_yticks([-3,0,3]);
ax.set_title('X point cloud',fontsize=15)

# ax = fig.add_subplot(432)
# ax.scatter(Y[0],Y[1], alpha=0.2, s=2, color='black');
# ax.set_aspect(1)
# # ax.set_ylim(-4,4);
# ax.set_xlabel('$y_1$',fontsize=17);
# ax.set_ylabel('$y_2$',fontsize=17);
# a1y,b1y = -Ysvd[0][0]
# line1 = ax.plot([-10*a1y,10*a1y],[-10*b1y,10*b1y], color=cmap(3), linewidth=3)[0];
# a2y,b2y = -Ysvd[0][1]
# line2 = ax.plot([-10*a2y,10*a2y],[-10*b2y,10*b2y], color=cmap(4), linewidth=3)[0];
# a3y,b3y = 1,0
# line3 = ax.plot([-10*a3y,10*a3y],[-10*b3y,10*b3y], color=cmap(5), linewidth=3)[0];
# ax.set_ylim(-4.3,4.3);
# ax.set_xlim(-3.6,3.6);
# ax.set_yticks([-3,0,3]);
# ax.set_title('Y point cloud',fontsize=15)

c=2
# fig = plt.figure(figsize=(10,10))
for iy,ay,by in zip(range(2,3),[a3y],[b3y]):
    for ix,ax,bx in zip(range(3),[a1,a2,a3],[b1,b2,b3]):
#         if iy==0: continue
#         if ix==1: continue
        ax_ = fig.add_subplot(1,4,(c))
        Y_line = ay*Y[0]+by*Y[1]
        X_line = ax*X2[0]+bx*X2[1]
        corr = (Y_line*X_line).sum()/np.sqrt((Y_line**2).sum()*(X_line**2).sum())
        ax_.scatter(X_line,Y_line, alpha=0.3, s=2, color = 'black', label = 'cross-correlation = {:.2f}'.format(corr));
        ax_.set_aspect(1)
        ax_.spines['bottom'].set_color(cmap(ix));
        ax_.tick_params(axis='x', colors=cmap(ix))
        ax_.set_xlabel('$xp_'+str(ix+1)+'$',fontsize=17, color=cmap(ix));
#         ax_.spines['left'].set_color(cmap(iy+3));
#         ax_.tick_params(axis='y', colors=cmap(iy+3))
        ax_.set_ylabel('$y$',fontsize=17);
        ax_.set_yticks([-4,-2,0,2,4]);
        # plt.legend(loc=1, fontsize=14);
        
        ax_.spines['bottom'].set_linewidth(3)

        leg = ax_.legend(handlelength=0, handletextpad=0, fancybox=True,loc=4, fontsize=14);
        for item in leg.legendHandles:
            item.set_visible(False)
            
        ax_.set_xlim(-4,4);
        c+=1

# %%
out = plt.hist(X2[0],density = 1)

# %%
out[0].sum()*(out[1][2]-out[1][1])
# Out:
# 1.0000000000000004

# %%
out
# Out:
# (array([0.00306477, 0.02298577, 0.08060344, 0.22127635, 0.36164279,
#         0.39045162, 0.272458  , 0.13362395, 0.03708371, 0.00919431]),
#  array([-3.36102423, -2.70844659, -2.05586895, -1.40329131, -0.75071367,
#         -0.09813603,  0.55444162,  1.20701926,  1.8595969 ,  2.51217454,
#          3.16475218]),
#  <a list of 10 Patch objects>)
